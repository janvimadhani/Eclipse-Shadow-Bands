# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d.axes3d import Axes3D, get_test_data
from matplotlib import cm
import mpl_toolkits.mplot3d.art3d as art3d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## LS 1 Balloon Array

# %%
"""
Channel 1
"""
data1 = np.genfromtxt("LS1CH1_5110.0-5180.0sec.txt", autostrip = True)
ls1_ch1_0x, ls1_ch1_0y = data1[:,0],data1[:,1]
data2 = np.genfromtxt("LS1CH1_5330.0-5400.0sec.txt", autostrip = True)
ls1_ch1_1x, ls1_ch1_1y = data2[:,0],data2[:,1]

"""
Channel 2
"""
data3 = np.genfromtxt("LS1CH2_5110.0-5180.0sec.txt", autostrip = True)
ls1_ch2_0x, ls1_ch2_0y = data3[:,0],data3[:,1]
data4 = np.genfromtxt("LS1CH2_5330.0-5400.0sec.txt", autostrip = True)
ls1_ch2_1x, ls1_ch2_1y = data4[:,0],data4[:,1]

"""
Channel 3
"""
data5 = np.genfromtxt("LS1CH3_5110.0-5180.0sec.txt", autostrip = True)
ls1_ch3_0x, ls1_ch3_0y = data5[:,0],data5[:,1]
data6 = np.genfromtxt("LS1CH3_5330.0-5400.0sec.txt", autostrip = True)
ls1_ch3_1x, ls1_ch3_1y = data6[:,0],data6[:,1]

"""
Channel 4
"""
data7 = np.genfromtxt("LS1CH4_5110.0-5180.0sec.txt", autostrip = True)
ls1_ch4_0x, ls1_ch4_0y = data7[:,0],data7[:,1]
data8 = np.genfromtxt("LS1CH4_5330.0-5400.0sec.txt", autostrip = True)
ls1_ch4_1x, ls1_ch4_1y = data8[:,0],data8[:,1]

# %% [markdown]
# ## LS 2 Ground Array - Balloon Equivalent

# %%
"""
Channel 1
"""
data9 = np.genfromtxt("LS2CH1_5110.0-5170.0sec.txt", autostrip = True)
ls2_ch1_0x, ls2_ch1_0y = data9[:,0],data9[:,1]
data10 = np.genfromtxt("LS2CH1_5330.0-5390.0sec.txt", autostrip = True)
ls2_ch1_1x, ls2_ch1_1y = data10[:,0],data10[:,1]

"""
Channel 2
"""
data11 = np.genfromtxt("LS2CH2_5110.0-5170.0sec.txt", autostrip = True)
ls2_ch2_0x, ls2_ch2_0y = data11[:,0],data11[:,1]
data12 = np.genfromtxt("LS2CH2_5330.0-5390.0sec.txt", autostrip = True)
ls2_ch2_1x, ls2_ch2_1y = data12[:,0],data12[:,1]

"""
Channel 3
"""
data13 = np.genfromtxt("LS2CH3_5110.0-5170.0sec.txt", autostrip = True)
ls2_ch3_0x, ls2_ch3_0y = data13[:,0],data13[:,1]
data14 = np.genfromtxt("LS2CH3_5330.0-5390.0sec.txt", autostrip = True)
ls2_ch3_1x, ls2_ch3_1y = data14[:,0],data14[:,1]

"""
Channel 4
"""
data15 = np.genfromtxt("LS2CH4_5110.0-5170.0sec.txt", autostrip = True)
ls2_ch4_0x, ls2_ch4_0y = data15[:,0],data15[:,1]
data16 = np.genfromtxt("LS2CH4_5330.0-5390.0sec.txt", autostrip = True)
ls2_ch4_1x, ls2_ch4_1y = data16[:,0],data16[:,1]

# %% [markdown]
# ## LS 3 Ground Array - Clear

# %%
"""
Channel 1
"""
data17 = np.genfromtxt("LS3CH1_5110.0-5170.0sec.txt", autostrip = True)
ls3_ch1_0x, ls3_ch1_0y = data17[:,0],data17[:,1]
data18 = np.genfromtxt("LS3CH1_5330.0-5390.0sec.txt", autostrip = True)
ls3_ch1_1x, ls3_ch1_1y = data18[:,0],data18[:,1]

"""
Channel 2
"""
data19 = np.genfromtxt("LS3CH2_5110.0-5170.0sec.txt", autostrip = True)
ls3_ch2_0x, ls3_ch2_0y = data19[:,0],data19[:,1]
data20 = np.genfromtxt("LS3CH2_5330.0-5390.0sec.txt", autostrip = True)
ls3_ch2_1x, ls3_ch2_1y = data20[:,0],data20[:,1]

"""
Channel 3
"""
data21 = np.genfromtxt("LS3CH3_5110.0-5170.0sec.txt", autostrip = True)
ls3_ch3_0x, ls3_ch3_0y = data21[:,0],data21[:,1]
data22 = np.genfromtxt("LS3CH3_5330.0-5390.0sec.txt", autostrip = True)
ls3_ch3_1x, ls3_ch3_1y = data22[:,0],data22[:,1]

"""
Channel 4
"""
data23 = np.genfromtxt("LS3CH4_5110.0-5170.0sec.txt", autostrip = True)
ls3_ch4_0x, ls3_ch4_0y = data23[:,0],data23[:,1]
data24 = np.genfromtxt("LS3CH4_5330.0-5390.0sec.txt", autostrip = True)
ls3_ch4_1x, ls3_ch4_1y = data24[:,0],data24[:,1]

# %% [markdown]
# ## LS 4 Ground Array - Blue Filtered

# %%
"""
Channel 1
"""
data25 = np.genfromtxt("LS4CH1_5110.0-5170.0sec.txt", autostrip = True)
ls4_ch1_0x, ls4_ch1_0y = data25[:,0],data25[:,1]
data26 = np.genfromtxt("LS4CH1_5330.0-5390.0sec.txt", autostrip = True)
ls4_ch1_1x, ls4_ch1_1y = data26[:,0],data26[:,1]

"""
Channel 2
"""
data27 = np.genfromtxt("LS4CH2_5110.0-5170.0sec.txt", autostrip = True)
ls4_ch2_0x, ls4_ch2_0y = data27[:,0],data27[:,1]
data28 = np.genfromtxt("LS4CH2_5330.0-5390.0sec.txt", autostrip = True)
ls4_ch2_1x, ls4_ch2_1y = data28[:,0],data28[:,1]

"""
Channel 3
"""
data29 = np.genfromtxt("LS4CH3_5110.0-5170.0sec.txt", autostrip = True)
ls4_ch3_0x, ls4_ch3_0y = data29[:,0],data29[:,1]
data30 = np.genfromtxt("LS4CH3_5330.0-5390.0sec.txt", autostrip = True)
ls4_ch3_1x, ls4_ch3_1y = data30[:,0],data30[:,1]

"""
Channel 4
"""
data31 = np.genfromtxt("LS4CH4_5110.0-5170.0sec.txt", autostrip = True)
ls4_ch4_0x, ls4_ch4_0y = data31[:,0],data31[:,1]
data32 = np.genfromtxt("LS4CH4_5330.0-5390.0sec.txt", autostrip = True)
ls4_ch4_1x, ls4_ch4_1y = data32[:,0],data32[:,1]

# %% [markdown]
# ## LS 5 Ground Array - Red Filtered

# %%
"""
Channel 1
"""
data33 = np.genfromtxt("LS5CH1_5110.0-5170.0sec.txt", autostrip = True)
ls5_ch1_0x, ls5_ch1_0y = data33[:,0],data33[:,1]
data34 = np.genfromtxt("LS5CH1_5330.0-5390.0sec.txt", autostrip = True)
ls5_ch1_1x, ls5_ch1_1y = data34[:,0],data34[:,1]

"""
Channel 2
"""
data35 = np.genfromtxt("LS5CH2_5110.0-5170.0sec.txt", autostrip = True)
ls5_ch2_0x, ls5_ch2_0y = data35[:,0],data35[:,1]
data36 = np.genfromtxt("LS5CH2_5330.0-5390.0sec.txt", autostrip = True)
ls5_ch2_1x, ls5_ch2_1y = data36[:,0],data36[:,1]

"""
Channel 3
"""
data37 = np.genfromtxt("LS5CH3_5110.0-5170.0sec.txt", autostrip = True)
ls5_ch3_0x, ls5_ch3_0y = data37[:,0],data37[:,1]
data38 = np.genfromtxt("LS5CH3_5330.0-5390.0sec.txt", autostrip = True)
ls5_ch3_1x, ls5_ch3_1y = data38[:,0],data38[:,1]

"""
Channel 4
"""
data39 = np.genfromtxt("LS5CH4_5110.0-5170.0sec.txt", autostrip = True)
ls5_ch4_0x, ls5_ch4_0y = data39[:,0],data39[:,1]
data40 = np.genfromtxt("LS5CH4_5330.0-5390.0sec.txt", autostrip = True)
ls5_ch4_1x, ls5_ch4_1y = data40[:,0],data40[:,1]

# %% [markdown]
# ## LS2 Spectrogram

# %%
fs = 600
y1 = ls5_ch1_0y
y2 = ls5_ch2_0y
y3 = ls5_ch3_0y
y4 = ls5_ch4_0y

f1, t1, Sxx1 = signal.spectrogram(y1, fs)
f2, t2, Sxx2 = signal.spectrogram(y2, fs)
f3, t3, Sxx3 = signal.spectrogram(y3, fs)
f4, t4, Sxx4 = signal.spectrogram(y4, fs)

# %%
print(len(f1),len(t1))
print(len(y1)/len(t1))

from matplotlib import cm
# Out:
# 129 160
# 225.31875

# %%
plt.figure(figsize=(15,10))


plt.subplot(221)
plt.pcolormesh(t1, f1, Sxx1,cmap='spectral')
plt.ylim(0,100)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.title('Channel 1')

plt.subplot(222)
plt.pcolormesh(t2, f2, Sxx2,cmap='spectral')
plt.ylim(0,100)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.title('Channel 2')

plt.subplot(223)
plt.pcolormesh(t3, f3, Sxx3,cmap='spectral')
plt.ylim(0,100)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.title('Channel 3')

plt.subplot(224)
plt.pcolormesh(t4, f4, Sxx4,cmap='spectral')
plt.ylim(0,100)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.title('Channel 4')

plt.tight_layout()
#plt.savefig('LS2SB.pdf')
# Out:
# /Users/JanviMadhani/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize=(12,8),frameon=False)
plt.pcolormesh(t2, f2, Sxx2,cmap='spectral')
plt.ylim(0,100)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.title('Channel 2 - LS4')
#plt.savefig('LS4CH2SB.pdf')
# Out:
# /Users/JanviMadhani/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## LS 1 Spectrogram

# %%
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
plt.plot(ls1_ch1_0x, ls1_ch1_0y)
plt.title('Channel 1')

plt.subplot(2,2,2)
plt.plot(ls1_ch2_0x, ls1_ch2_0y)
plt.title('Channel 2')

plt.subplot(2,2,3)
plt.plot(ls1_ch3_0x, ls1_ch3_0y)
plt.title('Channel 3')

plt.subplot(2,2,4)
plt.plot(ls1_ch4_0x, ls1_ch4_0y)
plt.title('Channel 4')

plt.tight_layout()
plt.show()

# %%
fs = 600
y5 = ls1_ch1_0y
y6 = ls1_ch2_0y
y7 = ls1_ch3_0y
y8 = ls1_ch4_0y

f5, t5, Sxx5 = signal.spectrogram(y5, fs)
f6, t6, Sxx6 = signal.spectrogram(y6, fs)
f7, t7, Sxx7 = signal.spectrogram(y7, fs)
f8, t8, Sxx8 = signal.spectrogram(y8, fs)

# %%
plt.figure(figsize=(16,10))

plt.subplot(2,2,1)
plt.pcolormesh(t5, f5, Sxx5,cmap='spectral')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.ylim(0,100)
plt.title('Channel 1')

plt.subplot(222)
plt.pcolormesh(t6, f6, Sxx6,cmap='spectral')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.ylim(0,100)
plt.title('Channel 2')

plt.subplot(223)
plt.pcolormesh(t7, f7, Sxx7,cmap='spectral')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.ylim(0,100)
plt.title('Channel 3')

plt.subplot(224)
plt.pcolormesh(t8, f8, Sxx8,cmap='spectral')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]')
plt.ylim(0,100)
plt.title('Channel 4')

plt.tight_layout()
#plt.savefig('LS1SB.pdf')
# Out:
# /Users/JanviMadhani/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(15,8))
plt.suptitle('Channel 1 - Balloon')

plt.subplot(211)
plt.pcolormesh(t7, f7, Sxx7,cmap='spectral')
plt.xticks(np.arange(70,step=10), ( '-70','-60', '-50','-40', '-30', '-20','-10'))
plt.ylabel('Frequency [Hz]')
plt.ylim(0,100)


plt.subplot(212)
plt.plot(ls1_ch3_0x-ls1_ch3_0x[0], ls1_ch3_0y,'k')
plt.xlabel('Time [s] Before Totality')
plt.ylabel('Voltage [V]')
plt.xticks(np.arange(70,step=10), ( '-70','-60', '-50','-40', '-30', '-20','-10'))
plt.xlim(0,69)

#plt.savefig('BalloonLCwCH1.pdf')
# Out:
# /Users/JanviMadhani/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize=(12,8))
plt.pcolormesh(t7, f7, Sxx7,cmap='jet')
#plt.ylim(0,100)
#plt.savefig('Balloon_channel3_sb.pdf')

# %%
t = t3
f = f3[5:20]
Sxx = Sxx3[5:20,:]

fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.w_zaxis.line.set_lw(0.)
ax.set_zticks([])
#ax._axis3don = False
t1 = np.linspace(0,max(t),len(t))
f1 = np.linspace(min(f),max(f),len(f))
tv,fv = np.meshgrid(t1,f1)
ax.plot_surface(tv,fv,Sxx,cmap='spectral')
#ax.set_zlim(0,0.0001)
#ax.set_ylim(5,50)
ax.set_xlabel('Time [s]')
ax.set_ylabel('Frequency [Hz]')
ax.view_init(azim=-30)
plt.show()
#ax.plot(t7,f7)
#plt.pcolormesh(t7, f7, Sxx7,cmap='jet')
#ax.imshow(Sxx7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5476f5e9e352> in <module>()
# ----> 1 t = t3
#       2 f = f3[5:20]
#       3 Sxx = Sxx3[5:20,:]
#       4
#       5 fig = plt.figure(figsize=(12,8))
#
# NameError: name 't3' is not defined

# %%
print(shape(t3))
print(shape(f3))
print(shape(Sxx3))
# Out:
# (160,)
# (129,)
# (129, 160)

# %%
print(shape(t))
print(shape(f))
print(shape(Sxx))
# Out:
# (160,)
# (15,)
# (15, 160)
